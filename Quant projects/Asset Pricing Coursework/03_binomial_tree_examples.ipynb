# %% [markdown]
# # Binomial Tree Examples
#
# This notebook is a smaller worked example notebook for binomial-tree pricing, replication, and option-value calculations.
#
# Use it as a compact companion to the discrete-time finance notebooks.

# %%
import pandas as pd
import numpy as np

# %%
S = 20
r= 0.04
T = 0.25
u=1.1
d=0.9
K = 21

# %%
Steps = 2
t = T/Steps

# %%
4.5*np.power(np.exp(1),-r*T)
# Out:
# 4.455224251871257

# %%
f_u=max(S*u-K,0)
f_d=max(S*d-K,0)
delta = (f_u - f_d) / (S*u-S*d)
p = (np.power(np.exp(1),r*T) - d) / (u-d)
f = np.power(np.exp(1),-r*T)*(p*f_u+(1-p)*f_d)

# %%
risk_neutral_ret=p*f_u+(1-p)*f_d

# %%
E_St = S*np.power(np.exp(1),r*T)

# %%
p_1 = (np.power(np.exp(1),r*t) - d) / (u-d)
f_1 = np.power(np.exp(1),-r*t)*(p*f_u+(1-p)*f_d)

# %%
f_uu=max(S*u*u-K,0)
f_ud=max(S*u*d-K,0)
f_dd=max(S*d*d-K,0)

# %%
f_1= np.power(np.exp(1),-2*r*t)*(np.power(p_1,2)*f_uu+2*p*(1-p)*f_ud+np.power(1-p,2)*f_dd)

# %%
def binomial_tree(stock,r, T, steps, K, u, d):
    S=stock
    t=T/steps
    int array [][] b = new int[steps+1][steps+1]
    for(int i = 0; i< steps+1; i++){
        for(int j=0; j<steps+1; j++){
            array[i][j]= S*np.power(u,i)

# %%
S_head
