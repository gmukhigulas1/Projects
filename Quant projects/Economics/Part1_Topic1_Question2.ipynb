# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
model = pd.read_csv("dataset_2025-04-12T17_48_03.282714077Z_DEFAULT_INTEGRATION_IMF.RES_WEO_6.0.0.csv", index_col=[4]).transpose()

# %%
model = model.iloc[6:].dropna().copy()

# %%
model.plot(figsize = (13,8), fontsize=12)
plt.title("Current & Constant GDP", fontsize = 20, color="Black")
plt.legend(fontsize=10)
plt.show()
