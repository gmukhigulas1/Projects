# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
model = pd.read_csv("dataset_2025-04-12T14_11_22.290990454Z_DEFAULT_INTEGRATION_IMF.FAD_FM_5.0.0.csv", index_col=[3]).transpose()

# %%
model = model.iloc[4:]

# %%
model.plot(figsize = (13,8), fontsize=12)
plt.legend(fontsize=10)
plt.show()
